# %%
import numpy as np
arr=np.array([2,4,5,6,4])

# %%
arr
# Out:
# array([2, 4, 5, 6, 4])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
print(arr.shape)
# Out:
# (5,)

# %%
arr.ndim
# Out:
# 1

# %%
import pandas as pd

# %%
df=pd.dataframe()
