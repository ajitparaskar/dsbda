# %%
# Step 1: Import libraries
import nltk
import re

# Download required resources (run once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Step 2: Sample text
text = "Tokenization is the first step in text analytics. It helps in breaking text into smaller parts."

# -------------------------------
# Step 3: Tokenization
# -------------------------------
print("Sentence Tokenization:")
sent_tokens = sent_tokenize(text)
print(sent_tokens)

print("\nWord Tokenization:")
word_tokens = word_tokenize(text)
print(word_tokens)

# -------------------------------
# Step 4: Stopwords Removal
# -------------------------------
stop_words = set(stopwords.words('english'))

# remove punctuation + lowercase
clean_text = re.sub('[^a-zA-Z]', ' ', text)
tokens = word_tokenize(clean_text.lower())

filtered_words = [w for w in tokens if w not in stop_words]

print("\nAfter Stopword Removal:")
print(filtered_words)

# -------------------------------
# Step 5: Stemming
# -------------------------------
ps = PorterStemmer()
stemmed_words = [ps.stem(w) for w in filtered_words]

print("\nStemmed Words:")
print(stemmed_words)

# -------------------------------
# Step 6: Lemmatization
# -------------------------------
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(w) for w in filtered_words]

print("\nLemmatized Words:")
print(lemmatized_words)

# -------------------------------
# Step 7: POS Tagging
# -------------------------------
print("\nPOS Tagging:")
pos_tags = nltk.pos_tag(word_tokens)
print(pos_tags)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ajitp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ajitp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ajitp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ajitp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Sentence Tokenization:
# ['Tokenization is the first step in text analytics.', 'It helps in breaking text into smaller parts.']
#
# Word Tokenization:
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', '.', 'It', 'helps', 'in', 'breaking', 'text', 'into', 'smaller', 'parts', '.']
#
# After Stopword Removal:
# ['tokenization', 'first', 'step', 'text', 'analytics', 'helps', 'breaking', 'text', 'smaller', 'parts']
#
# Stemmed Words:
# ['token', 'first', 'step', 'text', 'analyt', 'help', 'break', 'text', 'smaller', 'part']
#
# Lemmatized Words:
# ['tokenization', 'first', 'step', 'text', 'analytics', 'help', 'breaking', 'text', 'smaller', 'part']
#
# POS Tagging:
# [('Tokenization', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('first', 'JJ'), ('step', 'NN'), ('in', 'IN'), ('text', 'JJ'), ('analytics', 'NNS'), ('.', '.'), ('It', 'PRP'), ('helps', 'VBZ'), ('in', 'IN'), ('breaking', 'VBG'), ('text', 'NN'), ('into', 'IN'), ('smaller', 'JJR'), ('parts', 'NNS'), ('.', '.')]

# %%
# Step 1: Import library
from sklearn.feature_extraction.text import TfidfVectorizer

# Step 2: Documents
documentA = "Jupiter is the largest planet"
documentB = "Mars is the fourth planet from the sun"

documents = [documentA, documentB]

# Step 3: Create TF-IDF model
vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(documents)

# Step 4: Display results
print("\nFeature Names (Words):")
print(vectorizer.get_feature_names_out())

print("\nTF-IDF Matrix:")
print(tfidf_matrix.toarray())
# Out:
# Feature Names (Words):
# ['fourth' 'from' 'is' 'jupiter' 'largest' 'mars' 'planet' 'sun' 'the']
#
# TF-IDF Matrix:
# [[0.         0.         0.37930349 0.53309782 0.53309782 0.
#   0.37930349 0.         0.37930349]
#  [0.37695709 0.37695709 0.26820807 0.         0.         0.37695709
#   0.26820807 0.37695709 0.53641614]]
